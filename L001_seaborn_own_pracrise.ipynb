# %%
#Importera seaborn as följande:
#om man använder sbs.load_dataset och sedan i parantes namnet på ett testdataset från seaborn så laddar man in det:
#Sedan plottar man med sns.relplot och inom parantes x och y axel samt data = variabeln som du döpte datatestet till.
#För att hitta dataset sök på loaddataset seaborn github och välj sedan "tips" långt nere i listan

import seaborn as sns

test_data = sns.load_dataset("titanic")

test_data

#Visar de fem första raderna
#test_data.head()

#Visar de 5 sista raderna
#test_data.tail()

sns.relplot(x = "age", y= "pclass", data=test_data)
